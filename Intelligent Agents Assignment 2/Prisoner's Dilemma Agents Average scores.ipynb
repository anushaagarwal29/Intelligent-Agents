# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('FinalResults-Additional.csv', header = None)

# %%
df
# Out:
#                          0          1
# 0            HardT4TPlayer  399.09756
# 1        GrimTriggerPlayer  389.16240
# 2           TolerantPlayer  385.39117
# 3    Agarwal_Anusha_Player  385.30408
# 4         WinStayLoseShift  379.48254
# ..                     ...        ...
# 545          SoftT4TPlayer  378.51346
# 546             NicePlayer  358.48642
# 547           FreakyPlayer  324.00485
# 548            NastyPlayer  291.65915
# 549           RandomPlayer  277.45502
#
# [550 rows x 2 columns]

# %%
average_values = df.groupby(0)[1].mean()

# %%
# Sort the average values in descending order
average_values_sorted = average_values.sort_values(ascending=False)

# %%
print(average_values_sorted)
# Out:
# 0
# GrimTriggerPlayer        395.404780
# HardT4TPlayer            390.786362
# Agarwal_Anusha_Player    390.336214
# TolerantPlayer           387.468405
# T4TPlayer                386.263102
# SoftT4TPlayer            382.010062
# WinStayLoseShift         375.394603
# NicePlayer               363.592139
# FreakyPlayer             329.972102
# NastyPlayer              289.568468
# RandomPlayer             287.776144
# Name: 1, dtype: float64

# %%
# Plot the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(x=average_values_sorted.index, y=average_values_sorted.values, palette='viridis')

# Annotate scores on top of the bars
for i, v in enumerate(average_values_sorted.values):
    plt.text(i, v + 1, str(round(v, 2)), ha='center', va='bottom', fontsize=9)

plt.title('Average Scores Across 50 Tournaments for PD Strategies')
plt.xlabel('PD Strategies')
plt.ylabel('Average Score')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()
